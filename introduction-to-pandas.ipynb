# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimnesional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3452/4181734155.py in <module>
#       1 # DataFrame = 2-dimnesional
# ----> 2 car_data = pd.DataFrame({"Car make": series, "Colour": colours})
#       3 car_data
#
# NameError: name 'series' is not defined

# %%
# import data
car_sales = pd.read_csv("21708170-car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Export a DataFrame
car_sales.to_csv("exported-car-sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
## Attribute
car_sales.dtypes
# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b82018841ae> in <module>
# ----> 1 car_sales
#
# NameError: name 'car_sales' is not defined

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\arabd\AppData\Local\Temp/ipykernel_9560/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda","snake"],
                   index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18668/240837061.py in <module>
# ----> 1 car_sales.Odometer (KM)
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# car_sales[car_sales["Odometer (KM)"] > 100000]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20176/2847182809.py in <module>
# ----> 1 car_sales["Price"].plot()
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# C:\Users\arabd\AppData\Local\Temp/ipykernel_20176/2312081839.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv("22379919-car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17480/3802461933.py in <module>
# ----> 1 car_sales_missing
#
# NameError: name 'car_sales_missing' is not defined

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                    inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("22379919-car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Column from Series
seats_column = pd.Series([5, 5, 5, 5, 5])
# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
#Column from python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 6.4, 5.7, 7.1, 5.1, 8.4]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4

# %%
car_sales["Total Fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
#
#    Total Fuel used  Total Fuel used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# ...

# %%
# Create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
#
#    Total Fuel used  Total Fuel used (L)  Number of Wheels
# 0        11253.225            11253.225                 4
# ...

# %%
car_sales["Passed road Safety"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                   object
# Seats                  float64
# Fuel per 100KM         float64
# Total Fuel used        float64
# Total Fuel used (L)    float64
# Number of Wheels         int64
# Passed road Safety        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
#
#    Total Fuel used  Total Fuel used (L)  Number of Wheels  Passed road Safety
# ...

# %%
 car_sales = car_sales.drop("Total Fuel used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 6             2604.786                 4                True
# ...

# %%
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 7             3886.398                 4                True
# ...

# %%
# only select 20% of the data
car_sales_shuffled.sample(frac=0.2)
# Out:
#    index    Make Colour  Odometer (KM)  Doors      Price  Seats  \
# 0      5  Toyota  Green          99213      4  $4,500.00    5.0
# 6      9  Nissan  White          31600      4  $9,700.00    5.0
#
#    Fuel per 100KM  Total Fuel used (L)  Number of Wheels  Passed road Safety
# 0             6.4             6349.632                 4                True
# 6             8.4             2654.400                 4                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 1   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 0  Toyota  White         150043      4   $4,000.00    5.0             7.5
# 7   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 9  Nissan  White          31600      4   $9,700.00    5.0             8.4
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 4  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 8  Toyota  White          60000      4   $6,250.00    5.0             5.1
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 5             6349.632                 4                True
# ...

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 1  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 2  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White          31600      4   $9,700.00    5.0             8.4
# 5   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 8  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 9  Toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 0             3886.398                 4                True
# ...

# %%
car_sales = car_sales_shuffled
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0   Honda   Blue          54738      4   $7,000.00    5.0             7.1
# 1  Nissan  White         213095      4   $3,500.00    5.0             8.7
# 2  Toyota  White          60000      4   $6,250.00    5.0             5.1
# 3     BMW  Black          11179      5  $22,000.00    5.0             9.6
# 4  Nissan  White          31600      4   $9,700.00    5.0             8.4
# 5   Honda    Red          87899      4   $5,000.00    5.0             9.2
# 6   Honda   Blue          45698      4   $7,500.00    5.0             5.7
# 7  Toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 8  Toyota  Green          99213      4   $4,500.00    5.0             6.4
# 9  Toyota  White         150043      4   $4,000.00    5.0             7.5
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 0             3886.398                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100KM  \
# 0   Honda   Blue      34211.250      4   $7,000.00    5.0             7.1
# 1  Nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 2  Toyota  White      37500.000      4   $6,250.00    5.0             5.1
# 3     BMW  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  Nissan  White      19750.000      4   $9,700.00    5.0             8.4
# 5   Honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0             5.7
# 7  Toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 8  Toyota  Green      62008.125      4   $4,500.00    5.0             6.4
# 9  Toyota  White      93776.875      4   $4,000.00    5.0             7.5
#
#    Total Fuel used (L)  Number of Wheels  Passed road Safety
# 0             3886.398                 4                True
# ...

# %%
# try it, run your code
# Search for it
# try again
# ask

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                    inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].interpolate(),
                                    inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour   Odometer  Doors    Price
# 0  Toyota  White  150043.00    4.0   $4,000
# 1   Honda    Red   87899.00    4.0   $5,000
# 2  Toyota   Blue   49539.00    3.0   $7,000
# 3     BMW  Black   11179.00    5.0  $22,000
# 4  Nissan  White  213095.00    4.0   $3,500
# 5  Toyota  Green  174821.25    4.0   $4,500
# 6   Honda    NaN  136547.50    4.0   $7,500
# 7   Honda   Blue   98273.75    4.0      NaN
# 8  Toyota  White   60000.00    NaN      NaN
# 9     NaN  White   31600.00    4.0   $9,700

# %%
car_sales_missing = pd.read_csv("22379919-car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].interpolate(),
                                    inplace=True)

# %%
car_sales_missing

# %%
car_sales_missing.to_csv("car-sales-missingGaveen.csv")

# %%
car_sales_missing.fillna(car_sales_missing.interpolate(),
                                    inplace=True)

# %%
car_sales_missing

# %%
car_sales_missing.plot()
# Out:
# <AxesSubplot:>

# %%
# !pip install pyarrow

# %%
df=pd.read_parquet("input_dataset-2.parquet")

# %%
df
# Out:
#                      Unit_4_Power  Unit_4_Reactive Power  \
# timepoints
# 1970-12-19 09:51:44    262.204308               2.899036
# 1970-12-19 09:51:45    262.104319               3.344630
# 1970-12-19 09:51:46    262.004330               3.790223
# 1970-12-19 09:51:47    261.904340               4.235817
# 1970-12-19 09:51:48    261.804351               4.064759
# ...                           ...                    ...
# 1971-01-25 11:06:44    308.716025               3.974309
# 1971-01-25 11:06:45    308.746393               4.103262
# 1971-01-25 11:06:46    308.776762               4.472929
# 1971-01-25 11:06:47    308.807131               4.842597
# 1971-01-25 11:06:48    308.837499               5.212264
#
#                      Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# timepoints
# 1970-12-19 09:51:44                   82.279976                  173.955216
# 1970-12-19 09:51:45                   82.277248                  173.989815
# ...

# %%
df.to_csv("input_1.csv")

# %%
pred=pd.read_parquet("prediction_input.parquet")

# %%
pred
# Out:
#                      Unit_4_Power  Unit_4_Reactive Power  \
# timepoints
# 1971-01-25 11:06:49    308.867868               5.592261
# 1971-01-25 11:06:50    308.898237               6.251969
# 1971-01-25 11:06:51    308.928605               7.037091
# 1971-01-25 11:06:52    308.958974               7.822213
# 1971-01-25 11:06:53    308.989343               8.607335
# ...                           ...                    ...
# 1971-02-03 20:16:19    113.553752             -20.230184
# 1971-02-03 20:16:20    110.520494             -20.911359
# 1971-02-03 20:16:21    107.487618             -21.592784
# 1971-02-03 20:16:22    104.454741             -22.274208
# 1971-02-03 20:16:23    101.421865             -22.955633
#
#                      Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# timepoints
# 1971-01-25 11:06:49                   94.442351                  158.159044
# 1971-01-25 11:06:50                   94.445687                  158.202829
# ...

# %%
pred.to_csv("prediction_input.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
insert_index = 0
insert_colname = 'Price2'
insert_values = car_sales['Price'] # this can be a numpy array too
car_sales_missing.insert(loc=insert_index, column=insert_colname, value=insert_values)

# %%
car_sales_missing
# Out:
#        Price2    Make Colour  Odometer  Doors    Price
# 0   $4,000.00  Toyota  White  150043.0    4.0   $4,000
# 1   $5,000.00   Honda    Red   87899.0    4.0   $5,000
# 2   $7,000.00  Toyota   Blue       NaN    3.0   $7,000
# 3  $22,000.00     BMW  Black   11179.0    5.0  $22,000
# 4   $3,500.00  Nissan  White  213095.0    4.0   $3,500
# 5   $4,500.00  Toyota  Green       NaN    4.0   $4,500
# 6   $7,500.00   Honda    NaN       NaN    4.0   $7,500
# 7   $7,000.00   Honda   Blue       NaN    4.0      NaN
# 8   $6,250.00  Toyota  White   60000.0    NaN      NaN
# 9   $9,700.00     NaN  White   31600.0    4.0   $9,700

# %%
inp = pd.read_csv("data/input_dataset-2.csv") # file imported into jupyter
inp
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 0        1970-12-19 09:51:44    262.204308               2.899036
# 1        1970-12-19 09:51:45    262.104319               3.344630
# 2        1970-12-19 09:51:46    262.004330               3.790223
# 3        1970-12-19 09:51:47    261.904340               4.235817
# 4        1970-12-19 09:51:48    261.804351               4.064759
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 0                         82.279976                  173.955216
# ...

# %%
inp.to_excel("data/input.xml")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14124/969706352.py in <module>
# ----> 1 inp.to_excel("data/input.xml")
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2355             inf_rep=inf_rep,
#    2356         )
# -> 2357         formatter.write(
#    2358             excel_writer,
#    2359             sheet_name=sheet_name,
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     873         num_rows, num_cols = self.df.shape
# ...

# %%
inpp = inp.head(1000)

# %%
inpp.to_excel("data/input2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14124/1733238156.py in <module>
# ----> 1 inpp.to_excel("data/input2.xlsx")
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2355             inf_rep=inf_rep,
#    2356         )
# -> 2357         formatter.write(
#    2358             excel_writer,
#    2359             sheet_name=sheet_name,
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
# ...

# %%
df = inp.dropna()

# %%
df
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623   1970-12-29 10:59:57    311.093257               4.949223
# 805624   1970-12-29 10:59:58    311.103996               5.051777
# 805625   1970-12-29 10:59:59    311.114735               5.154330
# 805626   1970-12-29 11:00:00    311.125475               5.256883
# 805627   1970-12-29 11:00:01    311.136214               5.359436
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                    94.206187                  150.827828
# ...

# %%
# !pip install openpyxl ## library installed to handle xlsx file

# %%
df.to_excel(r'inputtt.xlsx', index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14124/2609970473.py in <module>
# ----> 1 df.to_excel(r'inputtt.xlsx', index = False)
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2355             inf_rep=inf_rep,
#    2356         )
# -> 2357         formatter.write(
#    2358             excel_writer,
#    2359             sheet_name=sheet_name,
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     900             # make sure to close opened file handles
# ...

# %%
df = df.head(1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20984/1136324024.py in <module>
# ----> 1 df = df.head(1000)
#
# NameError: name 'df' is not defined

# %%
df.to_excel("dataset.xlsx")

# %%
df = df.head(500)

# %%
df.to_excel("dataset.xlsx")

# %%
df = inp.dropna()

# %%
dff = df.head(10000)

# %%
dff.to_excel("dataset.xlsx")

# %%
df
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623   1970-12-29 10:59:57    311.093257               4.949223
# 805624   1970-12-29 10:59:58    311.103996               5.051777
# 805625   1970-12-29 10:59:59    311.114735               5.154330
# 805626   1970-12-29 11:00:00    311.125475               5.256883
# 805627   1970-12-29 11:00:01    311.136214               5.359436
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                    94.206187                  150.827828
# ...

# %%
inp
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 0        1970-12-19 09:51:44    262.204308               2.899036
# 1        1970-12-19 09:51:45    262.104319               3.344630
# 2        1970-12-19 09:51:46    262.004330               3.790223
# 3        1970-12-19 09:51:47    261.904340               4.235817
# 4        1970-12-19 09:51:48    261.804351               4.064759
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 0                         82.279976                  173.955216
# ...

# %%
df.to_excel("dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     891         try:
# --> 892             writer.write_cells(
#     893                 formatted_cells,
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\excel\_openpyxl.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     463             )
# --> 464             xcell.value, fmt = self._value_with_fmt(cell.val)
#     465             if fmt:
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\openpyxl\cell\cell.py in value(self, value)
#     214         """Set the value and infer type and display options."""
# --> 215         self._bind_value(value)
#     216
#
# ...

# %%
dff = df.head(50000)

# %%
dff
# Out:
#                  timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623  1970-12-29 10:59:57    311.093257               4.949223
# 805624  1970-12-29 10:59:58    311.103996               5.051777
# 805625  1970-12-29 10:59:59    311.114735               5.154330
# 805626  1970-12-29 11:00:00    311.125475               5.256883
# 805627  1970-12-29 11:00:01    311.136214               5.359436
# ...                     ...           ...                    ...
# 856573  1970-12-31 17:32:04    265.566803              18.155513
# 856574  1970-12-31 17:32:05    265.566803              18.555492
# 856575  1970-12-31 17:32:06    265.566803              18.955471
# 856576  1970-12-31 17:32:07    265.566803              19.355450
# 856577  1970-12-31 17:32:08    265.566803              19.755429
#
#         Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                   94.206187                  150.827828
# ...

# %%
dff.to_excel("dataset.xlsx")
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x0000029CAA598670>
# Traceback (most recent call last):
#   File "D:\Skill course\ML\sample_1\env\lib\zipfile.py", line 1807, in __del__
#     self.close()
#   File "D:\Skill course\ML\sample_1\env\lib\zipfile.py", line 1824, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# Exception ignored in: <function ZipFile.__del__ at 0x0000029CAA598670>
# Traceback (most recent call last):
#   File "D:\Skill course\ML\sample_1\env\lib\zipfile.py", line 1807, in __del__
#     self.close()
#   File "D:\Skill course\ML\sample_1\env\lib\zipfile.py", line 1824, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %%
df[90000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 90000
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[396588]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 396588
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
inp[396588]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 396588
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623   1970-12-29 10:59:57    311.093257               4.949223
# 805624   1970-12-29 10:59:58    311.103996               5.051777
# 805625   1970-12-29 10:59:59    311.114735               5.154330
# 805626   1970-12-29 11:00:00    311.125475               5.256883
# 805627   1970-12-29 11:00:01    311.136214               5.359436
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                    94.206187                  150.827828
# ...

# %%
display(df.iloc[80000])
# Out:
# timepoints                        1971-01-02 13:58:36
# Unit_4_Power                               302.461731
# Unit_4_Reactive Power                        0.491379
# Turbine_Guide Vane Opening                    91.4929
# Turbine_Pressure Drafttube                 154.634053
# Turbine_Pressure Spiral Casing            5298.915142
# Turbine_Rotational Speed                   108.010662
# mode                                        operation
# Bolt_1_Steel tmp                             2.730842
# Bolt_1_Tensile                            1612.883302
# Bolt_2_Tensile                            1492.700747
# Bolt_3_Tensile                            1691.429479
# Bolt_4_Tensile                            1601.383568
# Bolt_5_Tensile                            1637.671183
# Bolt_6_Tensile                             1679.63877
# Bolt_1_Torsion                             178.353976
# Bolt_2_Torsion                             164.191409
# ...

# %%
df
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623   1970-12-29 10:59:57    311.093257               4.949223
# 805624   1970-12-29 10:59:58    311.103996               5.051777
# 805625   1970-12-29 10:59:59    311.114735               5.154330
# 805626   1970-12-29 11:00:00    311.125475               5.256883
# 805627   1970-12-29 11:00:01    311.136214               5.359436
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                    94.206187                  150.827828
# ...

# %%
dff = df.head(10000)

# %%
dff.to_excel("dataset.xlsx")

# %%
inp
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 0        1970-12-19 09:51:44    262.204308               2.899036
# 1        1970-12-19 09:51:45    262.104319               3.344630
# 2        1970-12-19 09:51:46    262.004330               3.790223
# 3        1970-12-19 09:51:47    261.904340               4.235817
# 4        1970-12-19 09:51:48    261.804351               4.064759
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 0                         82.279976                  173.955216
# ...

# %%
d= inp.iloc[396300:396800]
d
# Out:
#                  timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 396300  1970-12-23 23:56:44    311.428467              15.474594
# 396301  1970-12-23 23:56:45    311.428467              15.510921
# 396302  1970-12-23 23:56:46    311.428467              15.547248
# 396303  1970-12-23 23:56:47    311.428467              15.583575
# 396304  1970-12-23 23:56:48    311.428467              15.619902
# ...                     ...           ...                    ...
# 396795  1970-12-24 03:58:47      0.000000              14.816023
# 396796  1970-12-24 03:58:48      0.000000              15.041182
# 396797  1970-12-24 03:58:49      0.000000              15.266341
# 396798  1970-12-24 03:58:50      0.000000              15.491500
# 396799  1970-12-24 03:58:51      0.000000              15.716660
#
#         Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 396300                   94.256248                  146.897296
# ...

# %%
d.to_excel("DA3_1.xlsx")

# %%
import numpy as np

# %%
d['mode'] = d['mode'].str.lower().replace({'operation': 1, 'start': 0})
# Out:
# C:\Users\arabd\AppData\Local\Temp/ipykernel_20984/2355700810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['mode'] = d['mode'].str.lower().replace({'operation': 1, 'start': 0})

# %%
d
# Out:
#                  timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 396476  1970-12-23 23:59:40    303.199578              15.622004
# 396477  1970-12-23 23:59:41    303.127733              15.618304
# 396478  1970-12-23 23:59:42    303.055889              15.614605
# 396479  1970-12-23 23:59:43    302.984044              15.610905
# 396480  1970-12-23 23:59:44    302.912199              15.607205
# ...                     ...           ...                    ...
# 396726  1970-12-24 03:57:38      0.000000              -0.719963
# 396727  1970-12-24 03:57:39      0.000000              -0.494803
# 396728  1970-12-24 03:57:40      0.000000              -0.269644
# 396729  1970-12-24 03:57:41      0.000000              -0.044485
# 396730  1970-12-24 03:57:42      0.000000               0.180674
#
#         Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 396476                   92.242065                  146.647380
# ...

# %%
d.dropna()
# Out:
# Empty DataFrame
# Columns: [timepoints, Unit_4_Power, Unit_4_Reactive Power, Turbine_Guide Vane Opening, Turbine_Pressure Drafttube, Turbine_Pressure Spiral Casing, Turbine_Rotational Speed, mode, Bolt_1_Steel tmp, Bolt_1_Tensile, Bolt_2_Tensile, Bolt_3_Tensile, Bolt_4_Tensile, Bolt_5_Tensile, Bolt_6_Tensile, Bolt_1_Torsion, Bolt_2_Torsion, Bolt_3_Torsion, Bolt_4_Torsion, Bolt_5_Torsion, Bolt_6_Torsion, lower_bearing_vib_vrt, turbine_bearing_vib_vrt]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.to_excel("DA3_nona.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     891         try:
# --> 892             writer.write_cells(
#     893                 formatted_cells,
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\excel\_openpyxl.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     459
# --> 460         for cell in cells:
#     461             xcell = wks.cell(
#
# D:\Skill course\ML\sample_1\env\lib\site-packages\pandas\io\formats\excel.py in get_formatted_cells(self)
#     828     def get_formatted_cells(self) -> Iterable[ExcelCell]:
# --> 829         for cell in itertools.chain(self._format_header(), self._format_body()):
# ...

# %%
d= inp.iloc[396100:3967200]
d
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 396100   1970-12-23 23:53:24    311.428467              14.052281
# 396101   1970-12-23 23:53:25    311.428467              14.092198
# 396102   1970-12-23 23:53:26    311.428467              14.132115
# 396103   1970-12-23 23:53:27    311.428467              14.172032
# 396104   1970-12-23 23:53:28    311.428467              14.211949
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 396100                    94.256248                  146.313613
# ...

# %%
a = pd.read_csv("input_dataset-2 - Copy.csv")

# %%
df = df.fillna(0)

# %%
df = df.dropna()
# Out:
#                   timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 805623   1970-12-29 10:59:57    311.093257               4.949223
# 805624   1970-12-29 10:59:58    311.103996               5.051777
# 805625   1970-12-29 10:59:59    311.114735               5.154330
# 805626   1970-12-29 11:00:00    311.125475               5.256883
# 805627   1970-12-29 11:00:01    311.136214               5.359436
# ...                      ...           ...                    ...
# 1874082  1971-01-25 11:06:44    308.716025               3.974309
# 1874083  1971-01-25 11:06:45    308.746393               4.103262
# 1874084  1971-01-25 11:06:46    308.776762               4.472929
# 1874085  1971-01-25 11:06:47    308.807131               4.842597
# 1874086  1971-01-25 11:06:48    308.837499               5.212264
#
#          Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 805623                    94.206187                  150.827828
# ...

# %%
c = b.iloc[396100:896900]
c
# Out:
#                  timepoints  Unit_4_Power  Unit_4_Reactive Power  \
# 396100  1970-12-23 23:53:24    311.428467              14.052281
# 396101  1970-12-23 23:53:25    311.428467              14.092198
# 396102  1970-12-23 23:53:26    311.428467              14.132115
# 396103  1970-12-23 23:53:27    311.428467              14.172032
# 396104  1970-12-23 23:53:28    311.428467              14.211949
# ...                     ...           ...                    ...
# 896895  1971-01-03 07:02:17    310.324740               7.297939
# 896896  1971-01-03 07:02:18    310.351899               6.978320
# 896897  1971-01-03 07:02:19    310.386479               6.693129
# 896898  1971-01-03 07:02:20    310.421058               6.407939
# 896899  1971-01-03 07:02:21    310.455638               6.122748
#
#         Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# 396100                   94.256248                  146.313613
# ...

# %%
c.to_excel("aaa.xlsx")
